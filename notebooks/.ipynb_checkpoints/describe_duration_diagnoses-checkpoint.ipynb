# %% [markdown]
# # Duration of Sick Notes and Associated Diagnoses
#
# This notebook provides descriptive statistics (mean and median) of the duration of sick notes and compares diagnoses associated with sick notes across COVID and comparator cohorts.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import seaborn as sns

from functools import reduce
from glob import glob

pd.options.mode.chained_assignment = None

# %%
# Function to parse string
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
# Read in and append input files
li = []

for file in glob('../output/cohorts/cohort_rates*.dta'):
    df_temp = pd.read_stata(file)
    # Creates date variable based on file name
    df_temp['cohort'] = file[find_nth(file, '_', 2)+1:-4]
    # Create population count
    df_temp['population'] = 1
    li.append(df_temp)
    
df_temp = pd.concat(li, axis=0, ignore_index=False).reset_index(drop=True)

# hospitalised COVID cohort
covid_hosp = df_temp.loc[(~df_temp.hosp_expo_date.isna()) & (df_temp.cohort == 'covid_2020')]
covid_hosp.cohort = 'covid_hosp_2020'
li.append(covid_hosp)

df_input = pd.concat(li, axis=0, ignore_index=False).reset_index(drop=True)

# %%
# Do not count those who had sick notes beyond end dates
df_input.loc[df_input.sick_note == 0, 'first_sick_note_duration'] = np.nan

# %%
# Columns to subset
diag_cols = [col for col in df_input if col.startswith('diag_')]
subset_cols = ['cohort','age_group','sex',
               'ethnicity','imd','region_string',
               'first_sick_note_duration',
               'sick_note','population'] + diag_cols

# Subset to relevant columns and do not count those beyond 
df_clean = df_input[subset_cols].rename(columns={'region_string':'region'})

# %% [markdown]
# _____

# %% [markdown]
# ## Duration

# %%
def compute_med_mean(path, demo=''):
    groups = ['cohort']
    if demo != '': 
        groups = ['cohort', demo]
    df_pct_ct = df_clean.groupby(
        groups)[['sick_note','population']].sum().reset_index()
    df_med = df_clean.groupby(
        groups)[['first_sick_note_duration']].apply(np.nanmedian).reset_index().rename(columns={0:'median_duration'})
    df_mean = df_clean.groupby(
        groups)[['first_sick_note_duration']].apply(np.nanmean).reset_index().rename(columns={0:'mean_duration'})
    df_pct25 = df_clean.groupby(
        groups)[['first_sick_note_duration']].apply(lambda x: np.nanpercentile(x,25)).reset_index().rename(columns={0:'pct_25'})
    df_pct75 = df_clean.groupby(
        groups)[['first_sick_note_duration']].apply(lambda x: np.nanpercentile(x,75)).reset_index().rename(columns={0:'pct_75'})
    dfs = [df_pct_ct, df_med, df_mean, df_pct25, df_pct75]
    df_out = reduce(
        lambda left,right: pd.merge(left,right,on=groups), dfs
    )
    Path("../output/tabfig/").mkdir(parents=True, exist_ok=True)
    df_out.to_csv('../output/tabfig/' + path + '.csv', index=False)
    return df_out

# %%
# Overall
compute_med_mean('med_mean_overall')
# Out:
#             cohort  sick_note  population  median_duration  mean_duration  \
# 0       covid_2020      679.0        1271            273.0     272.007364
# 1  covid_hosp_2020      245.0         479            262.0     265.085714
# 2     general_2019      506.0        1174            274.0     275.875248
# 3     general_2020      518.0         865            268.0     269.009653
# 4   pneumonia_2019      213.0         447            274.0     284.873239
#
#    pct_25  pct_75
# 0  224.50   316.5
# 1  210.00   315.0
# 2  223.00   317.0
# 3  220.25   314.0
# 4  235.00   320.0

# %%
# Age group
compute_med_mean('med_mean_age_group', 'age_group')
# Out:
#              cohort age_group  sick_note  population  median_duration  \
# 0        covid_2020      0-17       67.0         122            262.0
# 1        covid_2020     18-24       60.0         106            267.0
# 2        covid_2020     25-34       76.0         139            282.0
# 3        covid_2020     35-44       78.0         138            275.0
# 4        covid_2020     45-54      117.0         233            269.0
# 5        covid_2020     55-69      143.0         267            259.0
# 6        covid_2020     70-79       62.0         130            275.0
# 7        covid_2020       80+       76.0         136            276.0
# 8   covid_hosp_2020      0-17       27.0          49            259.0
# 9   covid_hosp_2020     18-24       25.0          41            260.0
# 10  covid_hosp_2020     25-34       27.0          49            292.0
# 11  covid_hosp_2020     35-44       29.0          56            273.0
# 12  covid_hosp_2020     45-54       41.0          79            251.0
# 13  covid_hosp_2020     55-69       55.0         110            247.0
# 14  covid_hosp_2020     70-79       19.0          45            262.0
# 15  covid_hosp_2020       80+       22.0          50            290.0
# 16     general_2019      0-17       54.0         122            277.5
# 17     general_2019     18-24       51.0         121            275.0
# 18     general_2019     25-34       53.0         116            277.0
# 19     general_2019     35-44       57.0         128            258.0
# 20     general_2019     45-54       88.0         225            279.5
# 21     general_2019     55-69      105.0         232            277.0
# 22     general_2019     70-79       50.0         109            232.0
# 23     general_2019       80+       48.0         121            284.5
# 24     general_2020      0-17       42.0          70            267.5
# 25     general_2020     18-24       45.0          87            256.0
# 26     general_2020     25-34       46.0          80            277.5
# 27     general_2020     35-44       57.0          90            267.0
# 28     general_2020     45-54      102.0         183            263.0
# 29     general_2020     55-69      107.0         178            271.0
# 30     general_2020     70-79       50.0          82            284.0
# 31     general_2020       80+       69.0          95            262.0
# 32   pneumonia_2019      0-17       30.0          53            289.5
# 33   pneumonia_2019     18-24       25.0          54            283.0
# 34   pneumonia_2019     25-34       23.0          47            286.0
# 35   pneumonia_2019     35-44       23.0          38            275.0
# 36   pneumonia_2019     45-54       30.0          81            289.5
# 37   pneumonia_2019     55-69       44.0          85            262.0
# 38   pneumonia_2019     70-79       21.0          49            296.0
# 39   pneumonia_2019       80+       17.0          40            250.0
#
#     mean_duration  pct_25  pct_75
# 0      268.820896  225.50  314.50
# 1      279.016667  233.25  324.50
# 2      290.013158  249.00  337.75
# 3      282.410256  232.50  335.50
# 4      264.393162  228.00  308.00
# 5      264.146853  209.00  312.00
# 6      270.532258  222.25  310.75
# 7      268.315789  228.75  318.00
# 8      282.481481  237.50  308.00
# 9      267.160000  190.00  317.00
# 10     273.333333  209.00  338.50
# 11     286.137931  242.00  319.00
# 12     247.195122  203.00  309.00
# 13     256.454545  206.50  311.00
# 14     246.052632  171.50  311.00
# 15     274.863636  246.50  319.50
# 16     280.351852  231.25  311.00
# 17     283.509804  231.00  316.50
# 18     281.358491  233.00  304.00
# 19     260.696429  202.00  302.25
# 20     290.079545  225.75  352.50
# 21     284.600000  236.00  317.00
# 22     235.120000  159.50  306.50
# 23     271.708333  238.00  322.00
# 24     274.642857  218.00  310.75
# 25     257.977778  199.00  289.00
# 26     285.304348  240.00  312.75
# 27     255.982456  216.00  303.00
# 28     262.323529  225.25  302.75
# 29     268.233645  222.00  320.00
# 30     280.360000  230.00  330.50
# 31     275.536232  209.00  309.00
# 32     296.533333  257.50  314.50
# 33     311.160000  242.00  322.00
# 34     307.086957  216.50  333.50
# 35     263.260870  199.00  333.00
# 36     291.266667  247.75  333.00
# 37     271.977273  216.00  298.75
# 38     302.000000  265.00  324.00
# 39     225.764706  194.00  298.00

# %%
# Sex
compute_med_mean('med_mean_sex', 'sex')
# Out:
#             cohort sex  sick_note  population  median_duration  mean_duration  \
# 0       covid_2020   F      337.0         631            267.0     265.026706
# 1       covid_2020   M      342.0         640            273.5     278.885965
# 2  covid_hosp_2020   F      128.0         245            259.0     254.062500
# 3  covid_hosp_2020   M      117.0         234            271.0     277.145299
# 4     general_2019   F      242.0         610            272.5     272.975207
# 5     general_2019   M      264.0         564            275.0     278.543726
# 6     general_2020   F      272.0         453            267.0     270.316176
# 7     general_2020   M      246.0         412            269.5     267.565041
# 8   pneumonia_2019   F       98.0         215            275.0     286.397959
# 9   pneumonia_2019   M      115.0         232            273.0     283.573913
#
#    pct_25  pct_75
# 0  218.00  313.00
# 1  231.00  325.50
# 2  197.50  310.75
# 3  219.00  329.00
# 4  214.75  312.00
# 5  231.00  321.00
# 6  218.75  316.00
# 7  224.25  310.75
# 8  229.75  323.75
# 9  236.00  318.00

# %%
# Ethnicity
compute_med_mean('med_mean_ethnicity', 'ethnicity')
# Out:
#              cohort               ethnicity  sick_note  population  \
# 0        covid_2020                   White      407.0         769
# 1        covid_2020  Asian or Asian British       57.0         101
# 2        covid_2020                   Other       47.0         100
# 3        covid_2020                 Unknown      168.0         301
# 4   covid_hosp_2020                   White      136.0         277
# 5   covid_hosp_2020  Asian or Asian British       25.0          45
# 6   covid_hosp_2020                   Other       17.0          37
# 7   covid_hosp_2020                 Unknown       67.0         120
# 8      general_2019                   White      316.0         706
# 9      general_2019  Asian or Asian British       34.0          78
# 10     general_2019                   Other       34.0          83
# 11     general_2019                 Unknown      122.0         307
# 12     general_2020                   White      316.0         523
# 13     general_2020  Asian or Asian British       46.0          76
# 14     general_2020                   Other       35.0          51
# 15     general_2020                 Unknown      121.0         215
# 16   pneumonia_2019                   White      131.0         264
# 17   pneumonia_2019  Asian or Asian British       18.0          38
# 18   pneumonia_2019                   Other       12.0          33
# 19   pneumonia_2019                 Unknown       52.0         112
#
#     median_duration  mean_duration  pct_25  pct_75
# 0             274.0     277.368550  229.00  318.00
# 1             268.0     266.614035  228.00  304.00
# 2             251.0     251.617021  200.00  300.00
# 3             264.0     266.553571  215.25  318.75
# 4             271.5     277.154412  220.00  320.25
# 5             267.0     259.880000  217.00  304.00
# 6             251.0     240.823529  194.00  290.00
# 7             255.0     248.686567  196.50  312.00
# 8             277.0     281.269841  228.50  324.00
# 9             256.5     273.323529  195.00  303.75
# 10            256.0     247.235294  175.25  299.75
# 11            272.5     270.639344  224.25  318.75
# 12            271.0     274.696203  224.75  319.00
# 13            242.5     250.978261  195.50  293.00
# 14            248.0     233.314286  183.00  288.00
# 15            270.0     271.338843  231.00  314.00
# 16            269.0     275.839695  230.00  311.50
# 17            293.0     325.111111  259.25  399.00
# 18            229.5     243.500000  181.50  308.25
# 19            299.0     303.250000  240.00  346.25

# %%
# IMD
compute_med_mean('med_mean_imd', 'imd')
# Out:
#              cohort  imd  sick_note  population  median_duration  \
# 0        covid_2020    0       33.0          58            262.0
# 1        covid_2020    1      137.0         271            262.0
# 2        covid_2020    2      137.0         257            273.0
# 3        covid_2020    3      123.0         218            274.0
# 4        covid_2020    4      145.0         244            273.0
# 5        covid_2020    5      104.0         223            275.0
# 6   covid_hosp_2020    0       16.0          28            264.5
# 7   covid_hosp_2020    1       42.0          90            255.5
# 8   covid_hosp_2020    2       47.0          96            255.0
# 9   covid_hosp_2020    3       53.0          89            274.0
# 10  covid_hosp_2020    4       50.0          89            268.5
# 11  covid_hosp_2020    5       37.0          87            247.0
# 12     general_2019    0       25.0          54            276.0
# 13     general_2019    1      103.0         227            278.0
# 14     general_2019    2       99.0         214            279.0
# 15     general_2019    3       96.0         230            273.0
# 16     general_2019    4       95.0         235            270.0
# 17     general_2019    5       88.0         214            270.0
# 18     general_2020    0       27.0          41            244.0
# 19     general_2020    1       84.0         176            286.5
# 20     general_2020    2      107.0         167            268.0
# 21     general_2020    3       97.0         157            272.0
# 22     general_2020    4      106.0         165            261.0
# 23     general_2020    5       97.0         159            264.0
# 24   pneumonia_2019    0        7.0          16            309.0
# 25   pneumonia_2019    1       51.0          91            296.0
# 26   pneumonia_2019    2       34.0          80            290.5
# 27   pneumonia_2019    3       46.0          85            268.5
# 28   pneumonia_2019    4       26.0          65            253.5
# 29   pneumonia_2019    5       49.0         110            261.0
#
#     mean_duration  pct_25  pct_75
# 0      264.909091  203.00  314.00
# 1      267.795620  220.00  312.00
# 2      276.708029  231.00  320.00
# 3      277.365854  228.00  332.00
# 4      273.889655  237.00  314.00
# 5      264.653846  208.00  314.25
# 6      268.562500  235.50  283.50
# 7      242.500000  181.00  311.75
# 8      264.936170  206.50  312.00
# 9      276.207547  228.00  339.00
# 10     270.980000  231.00  308.25
# 11     265.513514  200.00  327.00
# 12     287.680000  247.00  337.00
# 13     279.252427  220.50  330.50
# 14     291.858586  237.50  318.00
# 15     264.336842  215.50  309.50
# 16     262.410526  208.50  319.50
# 17     277.579545  233.50  298.75
# 18     241.037037  204.00  293.00
# 19     290.559524  235.75  339.50
# 20     263.953271  200.00  314.00
# 21     278.525773  237.00  314.00
# 22     250.009434  208.25  293.75
# 23     274.958763  223.00  309.00
# 24     303.285714  267.00  337.00
# 25     296.764706  257.00  323.50
# 26     300.588235  243.50  312.75
# 27     291.673913  228.00  317.25
# 28     259.307692  195.50  314.50
# 29     266.142857  198.00  302.00

# %%
# Region
compute_med_mean('med_mean_region', 'region')
# Out:
#              cohort                    region  sick_note  population  \
# 0        covid_2020                      East       79.0         136
# 1        covid_2020             East Midlands       61.0         108
# 2        covid_2020                    London      151.0         274
# 3        covid_2020                North East       63.0         131
# 4        covid_2020                North West       57.0         103
# 5        covid_2020                South East       82.0         146
# 6        covid_2020                South West       62.0         126
# 7        covid_2020             West Midlands       68.0         139
# 8        covid_2020  Yorkshire and The Humber       56.0         108
# 9   covid_hosp_2020                      East       26.0          52
# 10  covid_hosp_2020             East Midlands       27.0          52
# 11  covid_hosp_2020                    London       52.0          98
# 12  covid_hosp_2020                North East       19.0          49
# 13  covid_hosp_2020                North West       22.0          43
# 14  covid_hosp_2020                South East       32.0          50
# 15  covid_hosp_2020                South West       26.0          50
# 16  covid_hosp_2020             West Midlands       26.0          54
# 17  covid_hosp_2020  Yorkshire and The Humber       15.0          31
# 18     general_2019                      East       56.0         119
# 19     general_2019             East Midlands       43.0         112
# 20     general_2019                    London      100.0         224
# 21     general_2019                North East       66.0         141
# 22     general_2019                North West       51.0         114
# 23     general_2019                South East       49.0         117
# 24     general_2019                South West       42.0         116
# 25     general_2019             West Midlands       50.0         115
# 26     general_2019  Yorkshire and The Humber       49.0         116
# 27     general_2020                      East       40.0          82
# 28     general_2020             East Midlands       68.0          99
# 29     general_2020                    London      122.0         182
# 30     general_2020                North East       48.0          80
# 31     general_2020                North West       42.0          83
# 32     general_2020                South East       49.0          83
# 33     general_2020                South West       54.0          94
# 34     general_2020             West Midlands       47.0          79
# 35     general_2020  Yorkshire and The Humber       48.0          83
# 36   pneumonia_2019                      East       23.0          42
# 37   pneumonia_2019             East Midlands       28.0          54
# 38   pneumonia_2019                    London       53.0          97
# 39   pneumonia_2019                North East       22.0          46
# 40   pneumonia_2019                North West       11.0          28
# 41   pneumonia_2019                South East       17.0          47
# 42   pneumonia_2019                South West       18.0          39
# 43   pneumonia_2019             West Midlands       20.0          46
# 44   pneumonia_2019  Yorkshire and The Humber       21.0          48
#
#     median_duration  mean_duration  pct_25  pct_75
# 0             262.0     260.240506  209.00  295.00
# 1             259.0     250.737705  217.00  295.00
# 2             275.0     277.973510  231.50  324.00
# 3             283.0     287.396825  236.50  336.00
# 4             262.0     267.350877  234.00  304.00
# 5             268.0     273.536585  203.25  309.75
# 6             275.5     280.983871  229.50  315.50
# 7             273.0     274.294118  227.25  331.75
# 8             274.0     268.160714  228.75  339.50
# 9             263.5     256.576923  208.00  300.75
# 10            253.0     250.592593  210.00  293.50
# 11            259.5     252.153846  213.75  299.25
# 12            253.0     233.842105  137.00  315.50
# 13            254.5     254.545455  211.25  281.75
# 14            277.5     281.625000  226.00  321.25
# 15            292.5     310.615385  234.75  323.00
# 16            293.5     293.500000  254.50  336.25
# 17            229.0     242.333333  192.00  352.50
# 18            294.0     318.000000  256.25  355.00
# 19            264.0     263.534884  225.50  298.00
# 20            272.0     280.800000  219.25  322.75
# 21            257.0     268.696970  223.25  306.25
# 22            274.5     262.040000  217.00  323.75
# 23            268.0     253.285714  210.00  303.00
# 24            266.0     261.976190  214.75  300.00
# 25            279.5     281.940000  236.50  316.25
# 26            278.0     280.612245  225.00  309.00
# 27            269.5     262.700000  230.50  310.00
# 28            267.5     256.544118  224.00  300.25
# 29            261.0     265.065574  210.00  315.50
# 30            267.5     285.833333  232.50  324.50
# 31            248.0     255.380952  173.00  310.50
# 32            272.0     260.755102  205.00  303.00
# 33            268.5     286.907407  244.50  301.75
# 34            269.0     272.723404  209.00  326.50
# 35            292.0     281.708333  231.00  315.00
# 36            289.0     274.565217  236.00  317.00
# 37            293.5     310.357143  241.75  341.00
# 38            262.0     271.792453  217.00  310.00
# 39            270.5     280.954545  222.25  342.50
# 40            270.0     253.000000  234.00  289.00
# 41            281.0     315.176471  228.00  340.00
# 42            295.0     296.500000  259.25  314.50
# 43            267.5     272.150000  230.25  320.00
# 44            289.0     293.619048  213.00  321.00

# %% [markdown]
# _______

# %% [markdown]
# ## Associated Diagnoses

# %%
def create_plot(measure, ylabel):
    # Create barplot
    fig, ax = plt.subplots(figsize=(8,6))
    sns.barplot(x='cohort', y=measure, data=df_diag_sum, ax=ax)
    # Set title and axes labels
    title = measure[9:].replace("_", " ").title()
    ax.set_title(title)
    ax.set_xlabel('Cohort')
    ax.set_ylabel(ylabel)
    plt.show()
    Path("../output/tabfig/").mkdir(parents=True, exist_ok=True)
    fig.savefig('../output/tabfig/' + measure + '.png')

# %%
# Create flag
for c in diag_cols:
    df_clean.loc[~df_clean[c].isna(), 'num_' + c] = 1

# Sum sick notes and diagnoses by cohort
num_diag_cols = [col for col in df_clean if col.startswith('num_diag_')]
diag_subset_cols = ['cohort', 'sick_note'] + num_diag_cols
df_diag = df_clean[diag_subset_cols]
df_diag_sum = df_diag.groupby('cohort').sum().reset_index()

# Proportion of sick notes by diagnoses
for c in num_diag_cols:
    df_diag_sum['pct_diag_' + c[9:]] = (df_diag_sum[c]/df_diag_sum['sick_note'])*100
pct_cols = [col for col in df_diag_sum if col.startswith('pct_diag_')]

# %% [markdown]
# ### Number of Sick Notes by Diagnostic Category

# %%
for c in num_diag_cols:
    create_plot(c, 'No. of Diagnoses')

# %% [markdown]
# ### Proportion of Sick Notes by Diagnostic Category

# %%
for c in pct_cols:
    create_plot(c, '% of Sick Notes')
